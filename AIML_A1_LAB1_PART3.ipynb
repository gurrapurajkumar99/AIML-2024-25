# %% [markdown]
# <a href="https://colab.research.google.com/github/gurrapurajkumar99/AIML-2024-25/blob/main/AIML_A1_LAB1_PART3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import requests

# Replace with the raw URL of your file on GitHub
url = "https://github.com/2303A51795/AIML-2025-B12/blob/main/Lab01-Text.txt"

response = requests.get(url)
response.raise_for_status()  # Raise an exception if there's an error fetching the file

# Assuming the file is a text file, you can read it directly into pandas
from io import StringIO
df1 = pd.read_table(StringIO(response.text))

print(df1.head())  # Display the first few rows of the DataFrame
# Out:
#                                      <!DOCTYPE html>
# 0                                              <html
# 1                                          lang="en"
# 2    data-color-mode="auto" data-light-theme="lig...
# 3    data-a11y-animated-images="system" data-a11y...
# 4                                                  >

# %%
df1
# Out:
#                                         <!DOCTYPE html>
# 0                                                 <html
# 1                                             lang="en"
# 2       data-color-mode="auto" data-light-theme="lig...
# 3       data-a11y-animated-images="system" data-a11y...
# 4                                                     >
# ...                                                 ...
# 2133                                             </div>
# 2134      <div id="js-global-screen-reader-notice" c...
# 2135      <div id="js-global-screen-reader-notice-as...
# 2136                                            </body>
# 2137                                            </html>
#
# [2138 rows x 1 columns]

# %%
import os
print(os.path.isfile("Lab01-Text.csv"))
# Out:
# False

# %%
import os
print(os.getcwd())  # Shows the current working directory
# Out:
# /content

# %%
data3 = pd.read_excel("/full/path/to/your/file/Height_weight.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-1c7aa2e5debc> in <cell line: 1>()
# ----> 1 data3 = pd.read_excel("/full/path/to/your/file/Height_weight.xlsx")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     if not isinstance(io, ExcelFile):
#     503         should_close = True
# --> 504         io = ExcelFile(
#     505             io,
#     506             storage_options=storage_options,
#
# ...
